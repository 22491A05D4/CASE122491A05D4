# %% [markdown]
# <a href="https://colab.research.google.com/github/22491A05D4/CASE122491A05D4/blob/main/CSE4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as rajamouli
movie=['studentno.1','yamadhonga','maryadha ramanna','eega','RRR']
budget=[12,40,30,125,1200]
rajamouli.pie(budget,labels=movie)
ntr=rajamouli.Circle((0,0),0.6,color='white')
rajamouli.gca().add_artist(ntr)
rajamouli.show()

# %%
import matplotlib.pyplot as garu
in2013=[7,3,8]
in2014=[4,2,10]
in2015=[6,8,4]
actress=['trisha','kajal','anushka']
data=[in2013,in2014,in2015]
garu.boxplot(data,labels=actress)
garu.show()

# %%
import matplotlib.pyplot as bujji
marks=[0,0,7,8,2,2,3,4,2,7,10,10,8]
bujji.hist(marks,color='green',bins=10)
bujji.title('COMPUTER NETWORKS')
bujji.show()

# %%
import pandas as vijjulu
nickey=vijjulu.read_csv('jagan.csv')
print(nickey)
print(nickey.shape)
print(nickey.head(5))
#bottom
print(nickey.tail(3))
print(nickey.dtypes)
#J
print(nickey[nickey['Name'].str.startswith('J')])
# Out:
#                        Name       Date                             Target  \
# 0         YSR Rythu Bharosa  15-Oct-19                            Farmers
# 1                 Amma Vodi  09-Jan-20              Mothers and Guardians
# 2            YSR Aarogyasri  01-Apr-20                       BPL Families
# 3   Jagananna Vidya Deevena  27-Nov-19         Students from BPL Families
# 4        YSR Pension Kanuka  01-Jul-19  Senior Citizens, Disabled, Widows
# 5        YSR Housing Scheme  12-Jul-20                  Homeless Families
# 6      Jagananna Goru Mudda  21-Jan-20                    School Students
# 7              YSR Cheyutha  12-Aug-20     Women from SC/ST/BC/Minorities
# 8                 YSR Asara  11-Sep-20                          SHG Women
# 9          YSR Kapu Nestham  24-Jun-20          Women from Kapu Community
# 10          YSR Law Nestham  05-Dec-19                     Junior Lawyers
# 11          Jagananna Thodu  25-Nov-20                      Small Vendors
# ...

# %%
import pandas as vijjulu
nickey=vijjulu.read_csv('jagan.csv')
#print(nickey)
print(nickey.shape)
print(nickey.head(5))
#bottom
print(nickey.tail(3))
print(nickey.dtypes)
#J
#print(nickey[nickey['Name'].str.startswith('J')])
print(nickey[nickey['Name'].str.contains('Nestham')])
# Out:
# (15, 4)
#                       Name       Date                             Target  \
# 0        YSR Rythu Bharosa  15-Oct-19                            Farmers
# 1                Amma Vodi  09-Jan-20              Mothers and Guardians
# 2           YSR Aarogyasri  01-Apr-20                       BPL Families
# 3  Jagananna Vidya Deevena  27-Nov-19         Students from BPL Families
# 4       YSR Pension Kanuka  01-Jul-19  Senior Citizens, Disabled, Widows
#
#                            Amount
# 0                           13,500
# 1                           15,000
# 2                         5,00,000
# 3  Varies (full fee reimbursement)
# 4                            2,250
#                       Name       Date                      Target  \
# 12           YSR Jala Kala  28-Sep-20                     Farmers
# 13     Mana Badi Nadu-Nedu  14-Nov-19  Government School Students
# 14  YSR Matsyakara Bharosa  21-Nov-19                   Fishermen
#
#                          Amount
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

nickey=pd.read_csv('energy.csv')
print(nickey)
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
nickey=pd.read_csv('energy.csv')
print(nickey)
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
nickey=pd.read_csv('energy.csv')
print(nickey)
#line chart
#andhra, karnataka
srh=nickey[nickey['State']=='Andhra']
rcb=nickey[nickey['State']=='Karnataka']

fig,diag=plt.subplots(2)
#date, consumption
diag[0].plot(srh['Date'],srh['Consumption'],color='red')
diag[1].plot(rcb['Date'],rcb['Consumption'],color='green')
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sumanth=pd.read_csv('energy.csv')
print(sumanth)

srh=sumanth[sumanth['State']=='Andhra']
rcb=sumanth[sumanth['State']=='Karnataka']

fig,diag=plt.subplots(2)
diag[0].plot(srh['Date'],srh['Consumption'])
diag[1].plot(rcb['Date'],rcb['Consumption'])
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sumanth=pd.read_csv('energy.csv')
print(sumanth)

srh=sumanth[sumanth['State']=='Telengana']
rcb=sumanth[sumanth['State']=='Tripura']

fig,diag=plt.subplots(2)
diag[0].bar(srh['Date'],srh['Consumption'])
diag[1].bar(rcb['Date'],rcb['Consumption'])
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
# <BarContainer object of 6 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
sumanth=pd.read_csv('energy.csv')
print(sumanth)

srh=sumanth[sumanth['State']=='Telengana']
rcb=sumanth[sumanth['State']=='Tripura']

fig,diag=plt.subplots(2)
diag[0].bar(srh['Date'],srh['Consumption'].sum())
diag[1].bar(rcb['Date'],rcb['Consumption'].sum())

CSE4='Kerala'
CSE5='Delhi'
tdp=[CSE4,CSE5]


# Select only the 'Consumption' column and then calculate the sum
srh=sumanth[sumanth['State']=='Kerala']['Consumption'].sum()
rcb=sumanth[sumanth['State']=='Delhi']['Consumption'].sum()

ysr=[srh,rcb]

fig,diag=plt.subplots(2)
diag[0].pie(ysr,labels=tdp)
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
# ([<matplotlib.patches.Wedge at 0x7af5a9a2d480>,
# ...
#  [Text(-0.14982184583289132, 1.0897492438681595, 'Kerala'),
#   Text(0.1498218458328907, -1.0897492438681597, 'Delhi')])

# %%
import pandas as cr
import matplotlib.pyplot as lr
import seaborn as cse

ntr=cr.read_csv('heart.csv')
print(ntr)

#scatterplot
cse.scatterplot(x='age',y='bp',data=ntr,hue='gender')
lr.title('hear attack')
lr.xlabel('age')
lr.ylabel('cholestrol')
lr.show()

#linechart
cse.lineplot(x='age',y='cholestrol',data=ntr)
lr.show()
# Out:
#        age  gender  pain     bp  cholestrol  sugar  ecg  value  anigma  \
# 0     52.0       1     0  125.0       212.0      0    1  168.0       0
# 1     53.0       1     0  140.0       203.0      1    0    NaN       1
# 2     70.0       1     0  145.0       174.0      0    1  125.0       1
# 3     61.0       1     0    NaN         NaN      0    1  161.0       0
# 4     62.0       0     0  138.0       294.0      1    1    NaN       0
# ...    ...     ...   ...    ...         ...    ...  ...    ...     ...
# 1020  59.0       1     1  140.0       221.0      0    1  164.0       1
# 1021  60.0       1     0  125.0       258.0      0    0  141.0       1
# 1022  47.0       1     0  110.0       275.0      0    0  118.0       1
# 1023  50.0       0     0  110.0       254.0      0    0  159.0       0
# 1024  54.0       1     0  120.0       188.0      0    1  113.0       0
#
#       depression  vessel  target
# 0            1.0       3       0
# 1            3.1       3       0
# ...

# %%
cse.boxplot(x='target',y='value',data=ntr)
lr.show()

# %%
colour=['red','yellow']
cse.countplot(x='target',data=ntr,palette=colour)
lr.show()
# Out:
# <ipython-input-21-358b4ffe85c1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   cse.countplot(x='target',data=ntr,palette=colour)

# %%
cse.pairplot(ntr)
